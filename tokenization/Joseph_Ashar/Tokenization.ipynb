# %% [markdown]
# CSC 702 Mathematics of AI
# Group Project 4
# Tokenization

# %%
import numpy as np
import pandas as pd
# Out:
# Running cells with 'venv (Python -1.-1.-1)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"/Users/joseph/Projects/CSC 702/csc702_fall2025/Tokenization/Lucas_Wyatt/venv/bin/python" -m pip install ipykernel -U --force-reinstall'
