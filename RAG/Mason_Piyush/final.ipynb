# %%
import nbformat

input_path = r"C:\Users\mason\OneDrive\Desktop\702\csc702_fall2025\RAG\Mason_Piyush\AdvancedRAGComparison.ipynb"
output_path = r"C:\Users\mason\OneDrive\Desktop\702\csc702_fall2025\RAG\Mason_Piyush\AdvancedRAGComparison_final.ipynb"

with open(input_path, "r", encoding="utf-8") as f:
    nb = nbformat.read(f, as_version=nbformat.NO_CONVERT)  # do not force version

nb.metadata.pop("widgets", None)  # remove invalid widgets metadata

with open(output_path, "w", encoding="utf-8") as f:
    nbformat.write(nb, f)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 4
#       1 import nbformat
#       3 with open(r"C:\Users\mason\OneDrive\Desktop\702\csc702_fall2025\RAG\Mason_Piyush\AdvancedRAGComparison.ipynb", "r", encoding="utf-8") as f:
# ----> 4     nb = nbformat.read(f, as_version=5)
#       6 nb.metadata.pop("widgets", None)
#       8 with open(r"C:\Users\mason\OneDrive\Desktop\702\csc702_fall2025\RAG\Mason_Piyush\AdvancedRAGComparison_final.ipynb", "w", encoding="utf-8") as f:
#
# File c:\Users\mason\AppData\Local\Programs\Python\Python313\Lib\site-packages\nbformat\__init__.py:174, in read(fp, as_version, capture_validation_error, **kwargs)
#     171     with open(fp, encoding="utf8") as f:  # noqa: PTH123
#     172         return reads(f.read(), as_version, capture_validation_error, **kwargs)
# ...
